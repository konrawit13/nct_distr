# %% [markdown]
# **This file objective is to resampling the records to daily max-min of Alprazolam SKUs Inventory Stock movements

# %%
import os, ast, json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csv_path = 'C:/Users/user/Downloads/ปริมาณสินค้าคงคลัง_ยาขาดคราว - log2 (1).csv'

# %%
pd.set_option('display.max_columns', None)
sns.set_theme()

# %%
dtypes = {
    "ProductAll":"Float64",
    "ProductRemain":"Float64",
    "ProductAllocated":"Float64"
}

# %%
df = pd.read_csv(csv_path, thousands=",")

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196409 entries, 0 to 196408
# Data columns (total 16 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ProductCode          196409 non-null  object
#  1   GenericName          196409 non-null  object
#  2   TradeName            196409 non-null  object
#  3   ProductTypeName      195869 non-null  object
#  4   ProductPricePerUnit  196409 non-null  float64
#  5   ProductPrice         196409 non-null  int64
#  6   ProductStatus        196409 non-null  int64
#  7   ProductRemark        0 non-null       float64
#  8   ProductUnitCode      196409 non-null  object
#  9   ProductUnitName      196409 non-null  object
#  10  ProductAll           24342 non-null   float64
#  11  ProductRemain        196409 non-null  float64
#  12  ProductAllocated     196409 non-null  float64
#  13  LastUpdate           196409 non-null  object
#  14  enum_stock           193068 non-null  object
#  15  isRemoved            163869 non-null  object
# dtypes: float64(5), int64(2), object(9)
# memory usage: 24.0+ MB

# %% [markdown]
# <h1>Cleanse enum stock</h1>

# %%
df.loc[df['enum_stock'] == "FALSE", 'enum_stock'] = df.loc[df['enum_stock'] == "FALSE", 'isRemoved']

# %%
df.drop('isRemoved', axis=1, inplace=True)

# %% [markdown]
# <h1>Ensure 'LastUpdate' is a datetime object</h1>

# %%
df.loc[:, 'LastUpdate'] = pd.to_datetime(df['LastUpdate'])

# %% [markdown]
# <h1>Resample to Daily Max and Min</h1>

# %% [markdown]
# <h2>1. filter SKUs</h2>

# %%
df_alp_all = df.loc[df['TradeName'].str.contains('alprazolam', case=False)]

# %%
piv_alpra = df_alp_all['TradeName'].value_counts().reset_index()

# %%
alpra_tn_list = piv_alpra['TradeName'].tolist()

# %% [markdown]
# <h2>2. resampling SKUs</h2>

# %%
repop_alpra_df = pd.DataFrame()
for tradename in alpra_tn_list:
    dfloc = df_alp_all.loc[df_alp_all['TradeName'] == tradename].copy()
    dfindexed = dfloc.sort_values(by=['LastUpdate']).set_index('LastUpdate')
    dmax = dfindexed['ProductRemain'].resample('D').max().reset_index()
    dmax['TradeName'] = tradename
    dmin = dfindexed['ProductRemain'].resample('D').min().reset_index()
    dmin['TradeName'] = tradename
    repop_alpra_df = pd.concat([repop_alpra_df,dmax,dmin])
# Out:
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\pandas\core\indexes\base.py:7587: FutureWarning: Dtype inference on a pandas object (Series, Index, ExtensionArray) is deprecated. The Index constructor will keep the original dtype in the future. Call `infer_objects` on the result to get the old behavior.
#   return Index(sequences[0], name=names)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\pandas\core\indexes\base.py:7587: FutureWarning: Dtype inference on a pandas object (Series, Index, ExtensionArray) is deprecated. The Index constructor will keep the original dtype in the future. Call `infer_objects` on the result to get the old behavior.
#   return Index(sequences[0], name=names)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\pandas\core\indexes\base.py:7587: FutureWarning: Dtype inference on a pandas object (Series, Index, ExtensionArray) is deprecated. The Index constructor will keep the original dtype in the future. Call `infer_objects` on the result to get the old behavior.
#   return Index(sequences[0], name=names)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\pandas\core\indexes\base.py:7587: FutureWarning: Dtype inference on a pandas object (Series, Index, ExtensionArray) is deprecated. The Index constructor will keep the original dtype in the future. Call `infer_objects` on the result to get the old behavior.
#   return Index(sequences[0], name=names)

# %%
repop_alpra_df
# Out:
#    LastUpdate  ProductRemain                               TradeName
# 0  2024-10-07            0.0  Alprazolam tablets 0.25 mg (Polipharm)
# 1  2024-10-08            0.0  Alprazolam tablets 0.25 mg (Polipharm)
# 2  2024-10-09            0.0  Alprazolam tablets 0.25 mg (Polipharm)
# 3  2024-10-10         3340.0  Alprazolam tablets 0.25 mg (Polipharm)
# 4  2024-10-11         3217.0  Alprazolam tablets 0.25 mg (Polipharm)
# ..        ...            ...                                     ...
# 21 2024-10-28            0.0    Alprazolam CIV (200 mg, USP Ref std)
# 22 2024-10-29            0.0    Alprazolam CIV (200 mg, USP Ref std)
# 23 2024-10-30            0.0    Alprazolam CIV (200 mg, USP Ref std)
# 24 2024-10-31            0.0    Alprazolam CIV (200 mg, USP Ref std)
# 25 2024-11-01            0.0    Alprazolam CIV (200 mg, USP Ref std)
#
# [1828 rows x 3 columns]

# %%
repop_alpra_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1828 entries, 0 to 25
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   LastUpdate     1828 non-null   datetime64[ns]
#  1   ProductRemain  1828 non-null   float64
#  2   TradeName      1828 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 57.1+ KB

# %%
repop_alpra_df.loc[repop_alpra_df['LastUpdate'] == "2025-03-17"]
# Out:
#     LastUpdate  ProductRemain  \
# 161 2025-03-17        45469.0
# 161 2025-03-17        39970.0
# 161 2025-03-17        10581.0
# 161 2025-03-17        10243.0
# 161 2025-03-17        61219.0
# 161 2025-03-17        57718.0
#
#                                              TradeName
# 161             Alprazolam tablets 0.25 mg (Polipharm)
# 161             Alprazolam tablets 0.25 mg (Polipharm)
# 161  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/...
# 161  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/...
# 161              Alprazolam tablets 0.5 mg (Polipharm)
# 161              Alprazolam tablets 0.5 mg (Polipharm)

# %%
sorted_alpradf = repop_alpra_df.sort_values(by = ['LastUpdate'])

# %%
sorted_alpradf.loc[sorted_alpradf['LastUpdate']]

# %%
filtered_df = sorted_alpradf.loc[(sorted_alpradf['LastUpdate'] >= "2025-03-16") & (sorted_alpradf['LastUpdate'] <= "2025-03-18")]

# %%
filtered_df
# Out:
#     LastUpdate  ProductRemain  \
# 160 2025-03-16        45469.0
# 160 2025-03-16        45481.0
# 160 2025-03-16        61219.0
# 160 2025-03-16        10581.0
# 160 2025-03-16        10661.0
# 160 2025-03-16        61249.0
# 161 2025-03-17        10243.0
# 161 2025-03-17        45469.0
# 161 2025-03-17        39970.0
# 161 2025-03-17        10581.0
# 161 2025-03-17        57718.0
# 161 2025-03-17        61219.0
# 162 2025-03-18        45008.0
# 162 2025-03-18        10134.0
# 162 2025-03-18        10273.0
# 162 2025-03-18        59424.0
# 162 2025-03-18        44745.0
# 162 2025-03-18        59753.0
#
#                                              TradeName
# 160             Alprazolam tablets 0.25 mg (Polipharm)
# 160             Alprazolam tablets 0.25 mg (Polipharm)
# 160              Alprazolam tablets 0.5 mg (Polipharm)
# 160  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/...
# 160  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/...
# 160              Alprazolam tablets 0.5 mg (Polipharm)
# 161  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/...
# 161             Alprazolam tablets 0.25 mg (Polipharm)
# 161             Alprazolam tablets 0.25 mg (Polipharm)
# 161  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/...
# 161              Alprazolam tablets 0.5 mg (Polipharm)
# 161              Alprazolam tablets 0.5 mg (Polipharm)
# 162             Alprazolam tablets 0.25 mg (Polipharm)
# 162  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/...
# 162  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/...
# 162              Alprazolam tablets 0.5 mg (Polipharm)
# 162             Alprazolam tablets 0.25 mg (Polipharm)
# 162              Alprazolam tablets 0.5 mg (Polipharm)

# %%
pd.to_datetime("2024-03-17")
# Out:
# Timestamp('2024-03-17 00:00:00')

# %% [markdown]
# <h2>3. plot resampled</h2>

# %%
plt.figure(figsize=(16, 9))
sns.lineplot(
    data=repop_alpra_df,
    x='LastUpdate',
    y='ProductRemain',
    hue='TradeName',
    # marker='o', # Add markers for each data point
    errorbar=None
)
plt.title(f'Resampled All alprazolam SKUs ProductRemain Over Time', fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('ProductRemain(Units)', fontsize=12)
plt.legend(title='SKUs')

plt.show()

# %%
repop_alpra_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   LastUpdate     296 non-null    datetime64[ns]
#  1   ProductRemain  296 non-null    float64
#  2   TradeName      296 non-null    object
#  3   LastUpdate     296 non-null    datetime64[ns]
#  4   ProductRemain  296 non-null    float64
#  5   TradeName      296 non-null    object
#  6   LastUpdate     296 non-null    datetime64[ns]
#  7   ProductRemain  296 non-null    float64
#  8   TradeName      296 non-null    object
#  9   LastUpdate     296 non-null    datetime64[ns]
#  10  ProductRemain  296 non-null    float64
#  11  TradeName      296 non-null    object
#  12  LastUpdate     296 non-null    datetime64[ns]
#  13  ProductRemain  296 non-null    float64
#  14  TradeName      296 non-null    object
#  15  LastUpdate     296 non-null    datetime64[ns]
#  16  ProductRemain  296 non-null    float64
#  17  TradeName      296 non-null    object
#  18  LastUpdate     26 non-null     datetime64[ns]
#  19  ProductRemain  26 non-null     float64
#  20  TradeName      26 non-null     object
#  21  LastUpdate     26 non-null     datetime64[ns]
#  22  ProductRemain  26 non-null     float64
#  23  TradeName      26 non-null     object
# dtypes: datetime64[ns](8), float64(8), object(8)
# memory usage: 55.6+ KB

# %%
repop_alpra_df
# Out:
#     LastUpdate  ProductRemain                               TradeName  \
# 0   2024-10-07            0.0  Alprazolam tablets 0.25 mg (Polipharm)
# 1   2024-10-08            0.0  Alprazolam tablets 0.25 mg (Polipharm)
# 2   2024-10-09            0.0  Alprazolam tablets 0.25 mg (Polipharm)
# 3   2024-10-10         3340.0  Alprazolam tablets 0.25 mg (Polipharm)
# 4   2024-10-11         3217.0  Alprazolam tablets 0.25 mg (Polipharm)
# ..         ...            ...                                     ...
# 291 2025-07-25        39623.0  Alprazolam tablets 0.25 mg (Polipharm)
# 292 2025-07-26        39416.0  Alprazolam tablets 0.25 mg (Polipharm)
# 293 2025-07-27        39416.0  Alprazolam tablets 0.25 mg (Polipharm)
# 294 2025-07-28        39416.0  Alprazolam tablets 0.25 mg (Polipharm)
# 295 2025-07-29        39416.0  Alprazolam tablets 0.25 mg (Polipharm)
#
#     LastUpdate  ProductRemain                               TradeName  \
# 0   2024-10-07            0.0  Alprazolam tablets 0.25 mg (Polipharm)
# 1   2024-10-08            0.0  Alprazolam tablets 0.25 mg (Polipharm)
# 2   2024-10-09            0.0  Alprazolam tablets 0.25 mg (Polipharm)
# 3   2024-10-10            0.0  Alprazolam tablets 0.25 mg (Polipharm)
# 4   2024-10-11         2226.0  Alprazolam tablets 0.25 mg (Polipharm)
# ..         ...            ...                                     ...
# 291 2025-07-25        39416.0  Alprazolam tablets 0.25 mg (Polipharm)
# 292 2025-07-26        39416.0  Alprazolam tablets 0.25 mg (Polipharm)
# 293 2025-07-27        39416.0  Alprazolam tablets 0.25 mg (Polipharm)
# 294 2025-07-28        39416.0  Alprazolam tablets 0.25 mg (Polipharm)
# 295 2025-07-29        39246.0  Alprazolam tablets 0.25 mg (Polipharm)
#
#     LastUpdate  ProductRemain  \
# 0   2024-10-07            0.0
# 1   2024-10-08            0.0
# 2   2024-10-09            0.0
# 3   2024-10-10         7623.0
# 4   2024-10-11         7417.0
# ..         ...            ...
# 291 2025-07-25        23010.0
# 292 2025-07-26        22860.0
# 293 2025-07-27        22860.0
# 294 2025-07-28        22860.0
# 295 2025-07-29        22860.0
#
#                                              TradeName LastUpdate  \
# 0    Alprazolam tablet 1.0 mg (Polipharm) (100 tab/... 2024-10-07
# 1    Alprazolam tablet 1.0 mg (Polipharm) (100 tab/... 2024-10-08
# 2    Alprazolam tablet 1.0 mg (Polipharm) (100 tab/... 2024-10-09
# 3    Alprazolam tablet 1.0 mg (Polipharm) (100 tab/... 2024-10-10
# 4    Alprazolam tablet 1.0 mg (Polipharm) (100 tab/... 2024-10-11
# ..                                                 ...        ...
# 291  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/... 2025-07-25
# 292  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/... 2025-07-26
# 293  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/... 2025-07-27
# 294  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/... 2025-07-28
# 295  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/... 2025-07-29
#
#      ProductRemain                                          TradeName  \
# 0              0.0  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/...
# 1              0.0  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/...
# 2              0.0  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/...
# 3              0.0  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/...
# 4           5540.0  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/...
# ..             ...                                                ...
# 291        22860.0  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/...
# 292        22860.0  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/...
# 293        22860.0  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/...
# 294        22860.0  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/...
# 295        22826.0  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/...
#
#     LastUpdate  ProductRemain                              TradeName  \
# 0   2024-10-07            0.0  Alprazolam tablets 0.5 mg (Polipharm)
# 1   2024-10-08           82.0  Alprazolam tablets 0.5 mg (Polipharm)
# 2   2024-10-09          450.0  Alprazolam tablets 0.5 mg (Polipharm)
# 3   2024-10-10         7589.0  Alprazolam tablets 0.5 mg (Polipharm)
# 4   2024-10-11         7443.0  Alprazolam tablets 0.5 mg (Polipharm)
# ..         ...            ...                                    ...
# 291 2025-07-25        44903.0  Alprazolam tablets 0.5 mg (Polipharm)
# 292 2025-07-26        44774.0  Alprazolam tablets 0.5 mg (Polipharm)
# 293 2025-07-27        44774.0  Alprazolam tablets 0.5 mg (Polipharm)
# 294 2025-07-28        44414.0  Alprazolam tablets 0.5 mg (Polipharm)
# 295 2025-07-29        44408.0  Alprazolam tablets 0.5 mg (Polipharm)
#
#     LastUpdate  ProductRemain                              TradeName  \
# 0   2024-10-07            0.0  Alprazolam tablets 0.5 mg (Polipharm)
# 1   2024-10-08            0.0  Alprazolam tablets 0.5 mg (Polipharm)
# 2   2024-10-09            0.0  Alprazolam tablets 0.5 mg (Polipharm)
# 3   2024-10-10          150.0  Alprazolam tablets 0.5 mg (Polipharm)
# 4   2024-10-11         6561.0  Alprazolam tablets 0.5 mg (Polipharm)
# ..         ...            ...                                    ...
# 291 2025-07-25        44774.0  Alprazolam tablets 0.5 mg (Polipharm)
# 292 2025-07-26        44774.0  Alprazolam tablets 0.5 mg (Polipharm)
# 293 2025-07-27        44414.0  Alprazolam tablets 0.5 mg (Polipharm)
# 294 2025-07-28        44408.0  Alprazolam tablets 0.5 mg (Polipharm)
# 295 2025-07-29        44396.0  Alprazolam tablets 0.5 mg (Polipharm)
#
#     LastUpdate  ProductRemain                             TradeName  \
# 0   2024-10-07            1.0  Alprazolam CIV (200 mg, USP Ref std)
# 1   2024-10-08            0.0  Alprazolam CIV (200 mg, USP Ref std)
# 2   2024-10-09            0.0  Alprazolam CIV (200 mg, USP Ref std)
# 3   2024-10-10            0.0  Alprazolam CIV (200 mg, USP Ref std)
# 4   2024-10-11            0.0  Alprazolam CIV (200 mg, USP Ref std)
# ..         ...            ...                                   ...
# 291        NaT            NaN                                   NaN
# 292        NaT            NaN                                   NaN
# 293        NaT            NaN                                   NaN
# 294        NaT            NaN                                   NaN
# 295        NaT            NaN                                   NaN
#
#     LastUpdate  ProductRemain                             TradeName
# 0   2024-10-07            0.0  Alprazolam CIV (200 mg, USP Ref std)
# 1   2024-10-08            0.0  Alprazolam CIV (200 mg, USP Ref std)
# 2   2024-10-09            0.0  Alprazolam CIV (200 mg, USP Ref std)
# 3   2024-10-10            0.0  Alprazolam CIV (200 mg, USP Ref std)
# 4   2024-10-11            0.0  Alprazolam CIV (200 mg, USP Ref std)
# ..         ...            ...                                   ...
# 291        NaT            NaN                                   NaN
# 292        NaT            NaN                                   NaN
# 293        NaT            NaN                                   NaN
# 294        NaT            NaN                                   NaN
# 295        NaT            NaN                                   NaN
#
# [296 rows x 24 columns]

# %% [markdown]
# <h2>Plot original charts without any resampling</h2>

# %%
df.loc[df['TradeName'].str.contains('alprazolam', case=False)]
# Out:
#                                  ProductCode                    GenericName  \
# 19      3596649C-1D05-4E90-AFA9-952B417E12E8  Alprazolam tablet 0.25 mg/tab
# 25      46BC6DFB-5D08-4109-8F22-6CBE63393B92       Alprazolam tablet 1.0 mg
# 53      A48035C2-BF56-4067-BC59-B0D3F7393C35      Alprazolam tablets 0.5 mg
# 65      B80BA0BE-6147-41C3-B165-DFA84553E24E          Alprazolam (Standard)
# 109     3596649C-1D05-4E90-AFA9-952B417E12E8  Alprazolam tablet 0.25 mg/tab
# ...                                      ...                            ...
# 196304  46BC6DFB-5D08-4109-8F22-6CBE63393B92       Alprazolam tablet 1.0 mg
# 196323  A48035C2-BF56-4067-BC59-B0D3F7393C35      Alprazolam tablets 0.5 mg
# 196360  3596649C-1D05-4E90-AFA9-952B417E12E8  Alprazolam tablet 0.25 mg/tab
# 196364  46BC6DFB-5D08-4109-8F22-6CBE63393B92       Alprazolam tablet 1.0 mg
# 196383  A48035C2-BF56-4067-BC59-B0D3F7393C35      Alprazolam tablets 0.5 mg
#
#                                                 TradeName  \
# 19                 Alprazolam tablets 0.25 mg (Polipharm)
# 25      Alprazolam tablet 1.0 mg (Polipharm) (100 tab/...
# 53                  Alprazolam tablets 0.5 mg (Polipharm)
# 65                   Alprazolam CIV (200 mg, USP Ref std)
# 109                Alprazolam tablets 0.25 mg (Polipharm)
# ...                                                   ...
# 196304  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/...
# 196323              Alprazolam tablets 0.5 mg (Polipharm)
# 196360             Alprazolam tablets 0.25 mg (Polipharm)
# 196364  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/...
# 196383              Alprazolam tablets 0.5 mg (Polipharm)
#
#                         ProductTypeName  ProductPricePerUnit  ProductPrice  \
# 19                                  NaN                60.00             0
# 25                                  NaN                70.00             0
# 53                                  NaN                65.00             0
# 65                                  NaN             33216.28             0
# 109                                 NaN                60.00             0
# ...                                 ...                  ...           ...
# 196304  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                70.00             0
# 196323  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                65.00             0
# 196360  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                60.00             0
# 196364  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                70.00             0
# 196383  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                65.00             0
#
#         ProductStatus  ProductRemark                       ProductUnitCode  \
# 19                  0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 25                  0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 53                  0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 65                  0            NaN  12851F47-6355-4DEF-82BC-578C16E4ED41
# 109                 0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# ...               ...            ...                                   ...
# 196304              0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 196323              0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 196360              0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 196364              0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 196383              0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
#
#        ProductUnitName  ProductAll  ProductRemain  ProductAllocated  \
# 19                 Box         NaN            0.0             200.0
# 25                 Box         NaN            0.0               0.0
# 53                 Box         NaN            0.0            7364.0
# 65                vial         NaN            1.0               0.0
# 109                Box         NaN            0.0             200.0
# ...                ...         ...            ...               ...
# 196304             Box     23215.0        22826.0             389.0
# 196323             Box     45261.0        44396.0             865.0
# 196360             Box     39742.0        39246.0             496.0
# 196364             Box     23215.0        22826.0             389.0
# 196383             Box     45261.0        44396.0             865.0
#
#                  LastUpdate enum_stock
# 19      2024-10-07 11:22:48        NaN
# 25      2024-10-07 11:22:48        NaN
# 53      2024-10-07 11:22:48        NaN
# 65      2024-10-07 11:22:48        NaN
# 109     2024-10-07 12:14:49        NaN
# ...                     ...        ...
# 196304  2025-07-29 12:15:14       ปกติ
# 196323  2025-07-29 12:15:14       ปกติ
# 196360  2025-07-29 14:15:10       ปกติ
# 196364  2025-07-29 14:15:10       ปกติ
# 196383  2025-07-29 14:15:10       ปกติ
#
# [9952 rows x 15 columns]

# %%
df_alp_all = df.loc[df['TradeName'].str.contains('alprazolam', case=False)]

# %%
df_indexed = df_alp_all.sort_values(by=['LastUpdate']).set_index('LastUpdate')
# Out:
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\pandas\core\indexes\base.py:7587: FutureWarning: Dtype inference on a pandas object (Series, Index, ExtensionArray) is deprecated. The Index constructor will keep the original dtype in the future. Call `infer_objects` on the result to get the old behavior.
#   return Index(sequences[0], name=names)

# %%
grouped_resampled = df_indexed.groupby('ProductCode').resample('D')

# %%
df_alp_all
# Out:
#                                  ProductCode                    GenericName  \
# 19      3596649C-1D05-4E90-AFA9-952B417E12E8  Alprazolam tablet 0.25 mg/tab
# 25      46BC6DFB-5D08-4109-8F22-6CBE63393B92       Alprazolam tablet 1.0 mg
# 53      A48035C2-BF56-4067-BC59-B0D3F7393C35      Alprazolam tablets 0.5 mg
# 65      B80BA0BE-6147-41C3-B165-DFA84553E24E          Alprazolam (Standard)
# 109     3596649C-1D05-4E90-AFA9-952B417E12E8  Alprazolam tablet 0.25 mg/tab
# ...                                      ...                            ...
# 196304  46BC6DFB-5D08-4109-8F22-6CBE63393B92       Alprazolam tablet 1.0 mg
# 196323  A48035C2-BF56-4067-BC59-B0D3F7393C35      Alprazolam tablets 0.5 mg
# 196360  3596649C-1D05-4E90-AFA9-952B417E12E8  Alprazolam tablet 0.25 mg/tab
# 196364  46BC6DFB-5D08-4109-8F22-6CBE63393B92       Alprazolam tablet 1.0 mg
# 196383  A48035C2-BF56-4067-BC59-B0D3F7393C35      Alprazolam tablets 0.5 mg
#
#                                                 TradeName  \
# 19                 Alprazolam tablets 0.25 mg (Polipharm)
# 25      Alprazolam tablet 1.0 mg (Polipharm) (100 tab/...
# 53                  Alprazolam tablets 0.5 mg (Polipharm)
# 65                   Alprazolam CIV (200 mg, USP Ref std)
# 109                Alprazolam tablets 0.25 mg (Polipharm)
# ...                                                   ...
# 196304  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/...
# 196323              Alprazolam tablets 0.5 mg (Polipharm)
# 196360             Alprazolam tablets 0.25 mg (Polipharm)
# 196364  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/...
# 196383              Alprazolam tablets 0.5 mg (Polipharm)
#
#                         ProductTypeName  ProductPricePerUnit  ProductPrice  \
# 19                                  NaN                60.00             0
# 25                                  NaN                70.00             0
# 53                                  NaN                65.00             0
# 65                                  NaN             33216.28             0
# 109                                 NaN                60.00             0
# ...                                 ...                  ...           ...
# 196304  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                70.00             0
# 196323  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                65.00             0
# 196360  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                60.00             0
# 196364  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                70.00             0
# 196383  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                65.00             0
#
#         ProductStatus  ProductRemark                       ProductUnitCode  \
# 19                  0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 25                  0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 53                  0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 65                  0            NaN  12851F47-6355-4DEF-82BC-578C16E4ED41
# 109                 0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# ...               ...            ...                                   ...
# 196304              0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 196323              0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 196360              0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 196364              0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 196383              0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
#
#        ProductUnitName  ProductAll  ProductRemain  ProductAllocated  \
# 19                 Box         NaN            0.0             200.0
# 25                 Box         NaN            0.0               0.0
# 53                 Box         NaN            0.0            7364.0
# 65                vial         NaN            1.0               0.0
# 109                Box         NaN            0.0             200.0
# ...                ...         ...            ...               ...
# 196304             Box     23215.0        22826.0             389.0
# 196323             Box     45261.0        44396.0             865.0
# 196360             Box     39742.0        39246.0             496.0
# 196364             Box     23215.0        22826.0             389.0
# 196383             Box     45261.0        44396.0             865.0
#
#                  LastUpdate enum_stock
# 19      2024-10-07 11:22:48        NaN
# 25      2024-10-07 11:22:48        NaN
# 53      2024-10-07 11:22:48        NaN
# 65      2024-10-07 11:22:48        NaN
# 109     2024-10-07 12:14:49        NaN
# ...                     ...        ...
# 196304  2025-07-29 12:15:14       ปกติ
# 196323  2025-07-29 12:15:14       ปกติ
# 196360  2025-07-29 14:15:10       ปกติ
# 196364  2025-07-29 14:15:10       ปกติ
# 196383  2025-07-29 14:15:10       ปกติ
#
# [9952 rows x 15 columns]

# %%
plt.figure(figsize=(16, 9))
sns.lineplot(
    data=df_alp_all,
    x='LastUpdate',
    y='ProductRemain',
    hue='TradeName',
    # marker='o', # Add markers for each data point
    errorbar=None
)
plt.title(f'Original DataFrame All alprazolam SKUs ProductRemain Over Time', fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('ProductRemain(Units)', fontsize=12)
plt.legend(title='SKUs')

plt.show()

# %%
df_daily_max_custom = grouped_resampled.agg({
    'ProductRemain': 'max'
})

# %%
df_daily_max_custom.reset_index()
# Out:
#                               ProductCode LastUpdate  ProductRemain
# 0    3596649C-1D05-4E90-AFA9-952B417E12E8 2024-10-07            0.0
# 1    3596649C-1D05-4E90-AFA9-952B417E12E8 2024-10-08            0.0
# 2    3596649C-1D05-4E90-AFA9-952B417E12E8 2024-10-09            0.0
# 3    3596649C-1D05-4E90-AFA9-952B417E12E8 2024-10-10         3340.0
# 4    3596649C-1D05-4E90-AFA9-952B417E12E8 2024-10-11         3217.0
# ..                                    ...        ...            ...
# 909  B80BA0BE-6147-41C3-B165-DFA84553E24E 2024-10-28            0.0
# 910  B80BA0BE-6147-41C3-B165-DFA84553E24E 2024-10-29            0.0
# 911  B80BA0BE-6147-41C3-B165-DFA84553E24E 2024-10-30            0.0
# 912  B80BA0BE-6147-41C3-B165-DFA84553E24E 2024-10-31            0.0
# 913  B80BA0BE-6147-41C3-B165-DFA84553E24E 2024-11-01            0.0
#
# [914 rows x 3 columns]

# %% [markdown]
# <h1> Using loop approach for more control</h1>

# %%
def get_row_for_daily_max(group):
    # If there are multiple rows with the same max value, this picks the first one
    return group.loc[group['ProductRemain'].idxmax()]

# %%
enum_name_test = df_indexed['ProductCode'].value_counts()
enum_name_test.index.tolist()
# Out:
# ['097EBCD3-0F75-4AC0-98AA-A33B8AED586B',
#  '7C5C82A2-7C77-44DC-A562-7CC4C0E7F33D',
#  'D293AE7C-6DD0-454D-9A05-46198ADB74B4',
#  '7D8A86A4-7759-455E-A542-376B4D51A5EC',
#  '3596649C-1D05-4E90-AFA9-952B417E12E8',
#  '3081DCEA-C349-4933-A5C3-7CCEAF4A2DE1',
#  '2C9E68BB-DED0-4F45-AB39-CE75996B9875',
#  '2B4B64DA-8F3D-465E-8AB6-5CF1155B0F25',
#  '28FFCEF4-7098-405E-9037-E905D4D4B3A1',
#  '20024DAC-0DDE-48EF-B5B8-66BD529C1337',
#  '1C757FC0-8FC3-4103-AA3F-B98D638551AD',
#  '1AC8793E-6A02-44D5-A9A3-85A86CCEEDB0',
#  '140B3711-DB0E-43D7-A2E7-A002AEB87C07',
#  '0BC3546E-4F92-4F15-AEE4-07B4F24F26E8',
#  '8004A1EF-E908-40D5-85FE-7F6F17D9C0CC',
#  '3E8A1259-65AC-44B1-A3C0-23DBCE8DFBFE',
#  '7D18E35E-5F51-4E76-BE95-EFF080136D45',
#  'E39A3717-DB1A-49A7-B290-3EFD81984D7F',
#  '40CC4C8C-AAFA-4721-8AE2-EDEA1CFA63D9',
#  '77CE04AB-88E1-49A2-8B69-4809069146E9',
#  '779D4597-C1C2-44A8-BB3B-458417180FEE',
#  '77487114-F588-4EFA-88A9-099A2DD55702',
#  '768645F7-8646-494D-A4F4-C853EF595DC3',
#  '6F5A22E0-68F2-4734-A4B2-02F24155D291',
#  '733AC742-60DA-4A24-96DB-5ED11EFB4362',
#  '5F306A52-A191-4378-967E-8B2B7CBFAF06',
#  '5B193506-F5CD-4317-8237-C43303A653C3',
#  '579FF478-194B-47A4-A54E-2F87FA57299E',
#  '49BB51DF-84B0-44E5-8FE1-2695F04A809C',
#  '46BC6DFB-5D08-4109-8F22-6CBE63393B92',
#  '6D9D125F-7918-43E6-A98C-9EFAD6CA21E0',
#  '446768F7-EC9F-4009-B4C5-94666FACDE1C',
#  'E14994BC-39BE-4C67-B063-A00AB3D07D25',
#  '34765CA3-C35E-4F7F-9AF5-D649BC807E0E',
#  'A6528DF8-CB35-4773-AEA5-3B726950FC07',
#  'CF9B7F5C-FF61-4F5E-AC9E-2C6118D71949',
#  '704a211b-896a-40c7-b8e7-4655edf80f9b',
#  'CE6679C8-44D2-4DC4-9573-74F5895B6182',
#  'FC71BAE4-B40F-4B33-A3B9-CC3EBF23C373',
#  'A40623B1-0E31-46C6-A928-22B0C740461F',
#  'F66D1829-CE93-43E7-A5A5-53F44A87D28D',
#  'F66B4597-B645-4294-9CF5-056AFEC4C60D',
#  'A48035C2-BF56-4067-BC59-B0D3F7393C35',
#  '24b00027-b50b-47ec-ab23-565d094901e2',
#  'A9390303-63DA-47CB-B748-A0C4CB74FCAA',
#  'AD9D0A96-55C7-4D09-9C62-0E45EAA06372',
#  'EB311EBC-59F1-4688-8628-9EA3E742DB95',
#  'AEDC6670-DEB5-4715-A17F-9360A30708B5',
#  'AFA80EF2-C80C-4B45-9B85-13A8875A9A7B',
#  'AFAA7BDC-D320-46EA-BA62-D516E270D2BD',
#  'EAC4C871-8DF9-4A77-9588-9B8A5B5F3E5B',
#  '8F44962A-7C83-477D-80F9-ECDF7C72A4ED',
#  'DCE90DEC-BAEF-48A3-ADCB-1C82FC0917C7',
#  'E61182F7-4984-410A-8FC5-348A9198B554',
#  'E59B3A77-0CC4-468B-B03B-E6483983C9C0',
#  'F012AD04-73DE-4CC5-AC1F-DB7A8498517C',
#  '9122A29E-7808-4468-972D-283E456E0302',
#  'DE4EAAB8-E28F-4708-AFB9-ACCEF415CDA1',
#  'CC5C9F54-8AC9-4898-8015-DFB4B32C169C',
#  'd78e1ee7-4dcb-49f5-94fe-7a173b6cb6ec',
#  'fae155f3-1909-469c-ae8f-01a35bdd3b0a',
#  '57dce8ad-4653-48c6-9c32-0ce69648b1fd',
#  '7c597c2f-4043-4965-89b9-9bb044331345',
#  'D1B76517-EE01-4725-9248-3B7E114A9A17',
#  '7160D193-6318-4CAF-B11D-F2CC890E2636',
#  'A86531F6-9B50-493E-BFC1-086E8A9D2952',
#  'C9C719A4-886D-4025-8EAD-EFEC13E1A996',
#  '453306DE-B065-4155-9907-1A7B06F59378',
#  'DDB2C134-CF34-4292-8FDB-348897C0261E',
#  'D4DC5002-6E95-4B7C-92E6-93E6E8401AAF',
#  'AF63F480-CB42-487F-BD72-B531D987BAE2',
#  '47EB4015-44CA-4E60-8F62-43BE65B5E040',
#  'DF49B681-A53E-4350-B016-0BBA27FE66BC',
#  'B159F070-864B-4B8A-806A-A5A5CA20B72E',
#  '73263245-A0F5-4DEA-A73B-66E708BBA8EE',
#  '1FBC03A7-BE28-41EA-B97C-2972105A9A28',
#  '897CB76A-576A-4620-9C44-B81A2EC955DA',
#  '2AFC8FB9-96ED-43ED-8350-54C9301D6DF1',
#  '1C4D1E7D-5193-4083-8B33-F90A1E187C93',
#  'C8A88CF5-D218-4E73-AB61-0D47CDD08602',
#  '19BD1800-87C3-4CAF-B6C6-7985B208B96D',
#  '18099EC0-7971-406F-87C5-BDB0FDB090EB',
#  '8CFE1975-FFAD-4BCD-9090-F0EDB02FFE7E',
#  '10F0BE1C-781B-4833-BF6D-EECE4D7D3ACA',
#  '0C639E72-027B-4807-B6B9-0992AAB12137',
#  'BC3D1872-7622-481A-B79E-BF60BBD9FB1B',
#  '3BC2B22A-557B-46B3-82A5-CD08A12D2D41',
#  'C38E0908-9146-4848-8458-B0509A7F7514',
#  '916C7D29-17C3-4BC3-93D8-9B8C497447AD',
#  '2657FD3B-420D-4CE1-B51C-CC6BFE2893D3',
#  '92BD5135-5DDC-4AA2-8437-5E45464F8A4B',
#  'A3B97B18-F4DA-4E7D-924F-3B148C0E1FF4',
#  'B80BA0BE-6147-41C3-B165-DFA84553E24E',
#  '78F88139-8A9F-416B-9D89-D993EE1E5AAA',
#  'A45F8FAC-0D10-465C-BD50-C69540536A49',
#  'A6A35EA0-3C79-46C4-8785-13CDAD4B46E8',
#  'AE433AC9-A861-4BBE-A0D8-346CC1ADAF4D']

# %%
def resam_daily_max(idx_df, name_col):
    output_df = pd.DataFrame()
    enum_name = idx_df['ProductCode'].value_counts().index.tolist()
    for product_code in enum_name :
        filtered_df = idx_df.loc[idx_df[name_col] == product_code]
        df_daily_max_rows = filtered_df.groupby(filtered_df.index.date).apply(get_row_for_daily_max)
        output_df = pd.concat([output_df,df_daily_max_rows])
    return output_df

# %%
piv = df_indexed['TradeName'].value_counts().reset_index()

# %%
piv.loc[piv['TradeName'].str.contains('Alprazolam', case=False)]
# Out:
#                                             TradeName  count
# 5              Alprazolam tablets 0.25 mg (Polipharm)   3229
# 28  Alprazolam tablet 1.0 mg (Polipharm) (100 tab/...   3229
# 44              Alprazolam tablets 0.5 mg (Polipharm)   3229
# 66               Alprazolam CIV (200 mg, USP Ref std)    265

# %%
piv.iloc[5,0]
# Out:
# 'Alprazolam tablets 0.25 mg (Polipharm)'

# %%
alp_tname1 = piv.iloc[5,0]

# %%
df_indexed.loc[df_indexed['TradeName'] == 'Concerta tablets 18 mg (30 tab/bot)']

# %%
# df_mpd18mg = df2.loc[df2['GenericName'] == 'Methylphenidate HCl extended release tablets 18 mg']
df_mpd18mg = df_indexed.loc[df_indexed['TradeName'] == alp_tname1]

# %%
resam_d = resam_daily_max(df_indexed, 'ProductCode')

# %%
resam_df = resam_d.reset_index().rename({'index':'LastUpdate'}, axis=1)

# %%
resam_df
# Out:
#        LastUpdate                           ProductCode  \
# 0      2024-10-07  097EBCD3-0F75-4AC0-98AA-A33B8AED586B
# 1      2024-10-08  097EBCD3-0F75-4AC0-98AA-A33B8AED586B
# 2      2024-10-09  097EBCD3-0F75-4AC0-98AA-A33B8AED586B
# 3      2024-10-10  097EBCD3-0F75-4AC0-98AA-A33B8AED586B
# 4      2024-10-11  097EBCD3-0F75-4AC0-98AA-A33B8AED586B
# ...           ...                                   ...
# 18011  2024-10-25  AE433AC9-A861-4BBE-A0D8-346CC1ADAF4D
# 18012  2024-10-26  AE433AC9-A861-4BBE-A0D8-346CC1ADAF4D
# 18013  2024-10-27  AE433AC9-A861-4BBE-A0D8-346CC1ADAF4D
# 18014  2024-10-28  AE433AC9-A861-4BBE-A0D8-346CC1ADAF4D
# 18015  2024-10-29  AE433AC9-A861-4BBE-A0D8-346CC1ADAF4D
#
#                                              GenericName  \
# 0                   Pethidine HCl injection 50 mg/ml/amp
# 1                   Pethidine HCl injection 50 mg/ml/amp
# 2                   Pethidine HCl injection 50 mg/ml/amp
# 3                   Pethidine HCl injection 50 mg/ml/amp
# 4                   Pethidine HCl injection 50 mg/ml/amp
# ...                                                  ...
# 18011  Methylphenidate HCl modified release hard caps...
# 18012  Methylphenidate HCl modified release hard caps...
# 18013  Methylphenidate HCl modified release hard caps...
# 18014  Methylphenidate HCl modified release hard caps...
# 18015  Methylphenidate HCl modified release hard caps...
#
#                                           TradeName  \
# 0      Pethidine HCl inj. 50 mg/ml/amp (10 amp/box)
# 1      Pethidine HCl inj. 50 mg/ml/amp (10 amp/box)
# 2      Pethidine HCl inj. 50 mg/ml/amp (10 amp/box)
# 3      Pethidine HCl inj. 50 mg/ml/amp (10 amp/box)
# 4      Pethidine HCl inj. 50 mg/ml/amp (10 amp/box)
# ...                                             ...
# 18011                              Ritalin LA 20 mg
# 18012                              Ritalin LA 20 mg
# 18013                              Ritalin LA 20 mg
# 18014                              Ritalin LA 20 mg
# 18015                              Ritalin LA 20 mg
#
#                         ProductTypeName  ProductPricePerUnit  ProductPrice  \
# 0                                   NaN                 80.0             0
# 1      (ยส. 2) ยาเสพติดให้โทษในประเภท 2                 80.0             0
# 2      (ยส. 2) ยาเสพติดให้โทษในประเภท 2                 80.0             0
# 3      (ยส. 2) ยาเสพติดให้โทษในประเภท 2                 80.0             0
# 4      (ยส. 2) ยาเสพติดให้โทษในประเภท 2                 80.0             0
# ...                                 ...                  ...           ...
# 18011   (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2               1200.0             0
# 18012   (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2               1200.0             0
# 18013   (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2               1200.0             0
# 18014   (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2               1200.0             0
# 18015   (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2               1200.0             0
#
#        ProductStatus  ProductRemark                       ProductUnitCode  \
# 0                  0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 1                  0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 2                  0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 3                  0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 4                  0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# ...              ...            ...                                   ...
# 18011              0            NaN  4CE8E50B-80B3-4003-B2B6-9D08C97DD814
# 18012              0            NaN  4CE8E50B-80B3-4003-B2B6-9D08C97DD814
# 18013              0            NaN  4CE8E50B-80B3-4003-B2B6-9D08C97DD814
# 18014              0            NaN  4CE8E50B-80B3-4003-B2B6-9D08C97DD814
# 18015              0            NaN  4CE8E50B-80B3-4003-B2B6-9D08C97DD814
#
#       ProductUnitName  ProductAll  ProductRemain  ProductAllocated enum_stock
# 0                 Box         NaN        25095.0             518.0        NaN
# 1                 Box         NaN        25019.0             485.0        NaN
# 2                 Box         NaN        24548.0             589.0       ปกติ
# 3                 Box         NaN        23991.0             779.0       ปกติ
# 4                 Box         NaN        23748.0             700.0       ปกติ
# ...               ...         ...            ...               ...        ...
# 18011          Bottle         NaN            0.0               0.0  ยาขาดคราว
# 18012          Bottle         NaN            0.0               0.0  ยาขาดคราว
# 18013          Bottle         NaN            0.0               0.0  ยาขาดคราว
# 18014          Bottle         NaN            0.0               0.0  ยาขาดคราว
# 18015          Bottle         NaN            0.0               0.0  ยาขาดคราว
#
# [18016 rows x 15 columns]

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=resam_df,
             x='LastUpdate',
             y='ProductRemain',
             hue='GenericName',
             # marker='o',
             errorbar=None)
plt.title('Time-Series of Product Remain by Generic Name')
plt.xlabel('Timestamp')
# Out:
# Text(0.5, 0, 'Timestamp')
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 3650 (\N{THAI CHARACTER SARA O}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 3617 (\N{THAI CHARACTER MO MA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 3604 (\N{THAI CHARACTER DO DEK}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 3629 (\N{THAI CHARACTER O ANG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 3660 (\N{THAI CHARACTER THANTHAKHAT}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 3609 (\N{THAI CHARACTER NO NU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 3652 (\N{THAI CHARACTER SARA AI MAIMALAI}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 3626 (\N{THAI CHARACTER SO SUA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 3605 (\N{THAI CHARACTER TO TAO}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 3633 (\N{THAI CHARACTER MAI HAN-AKAT}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 3615 (\N{THAI CHARACTER FO FAN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3650 (\N{THAI CHARACTER SARA O}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3617 (\N{THAI CHARACTER MO MA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3604 (\N{THAI CHARACTER DO DEK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3629 (\N{THAI CHARACTER O ANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3660 (\N{THAI CHARACTER THANTHAKHAT}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3609 (\N{THAI CHARACTER NO NU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3652 (\N{THAI CHARACTER SARA AI MAIMALAI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3626 (\N{THAI CHARACTER SO SUA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3605 (\N{THAI CHARACTER TO TAO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3633 (\N{THAI CHARACTER MAI HAN-AKAT}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3615 (\N{THAI CHARACTER FO FAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
summed_value_per_timestamp = resam_df.groupby(by=['LastUpdate'])['ProductRemain'].sum().reset_index()

# %%
summed_value_per_timestamp.reset_index()
# Out:
#      LastUpdate  ProductRemain
# 0    2024-10-07      1167669.0
# 1    2024-10-08      1163303.0
# 2    2024-10-09      1145428.0
# 3    2024-10-10      1197740.0
# 4    2024-10-11      1249017.0
# ..          ...            ...
# 291  2025-07-25      1428488.0
# 292  2025-07-26      1402869.0
# 293  2025-07-27      1402629.0
# 294  2025-07-28      1400072.0
# 295  2025-07-29      1399656.0
#
# [296 rows x 2 columns]

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=summed_value_per_timestamp,
             x='LastUpdate',
             y='ProductRemain',
             # hue='GenericName',
             # marker='o',
             errorbar=None)
plt.title('Time-Series of Product Remain sum')
plt.xlabel('Timestamp')
plt.ylabel('Unit(s)')
# Out:
# Text(0, 0.5, 'Unit(s)')

# %%
resam_df.to_csv('C:/Users/user/Downloads/nrf_invent_max_redis2025-07-31.csv',encoding='utf-8')

# %%
df_daily_max_rows = df_mpd18mg.groupby(df_mpd18mg.index.date).apply(get_row_for_daily_max)

# %%
df_daily_max_rows.reset_index()
# Out:
#           index                           ProductCode  \
# 0    2024-10-07  3596649C-1D05-4E90-AFA9-952B417E12E8
# 1    2024-10-08  3596649C-1D05-4E90-AFA9-952B417E12E8
# 2    2024-10-09  3596649C-1D05-4E90-AFA9-952B417E12E8
# 3    2024-10-10  3596649C-1D05-4E90-AFA9-952B417E12E8
# 4    2024-10-11  3596649C-1D05-4E90-AFA9-952B417E12E8
# ..          ...                                   ...
# 291  2025-07-25  3596649C-1D05-4E90-AFA9-952B417E12E8
# 292  2025-07-26  3596649C-1D05-4E90-AFA9-952B417E12E8
# 293  2025-07-27  3596649C-1D05-4E90-AFA9-952B417E12E8
# 294  2025-07-28  3596649C-1D05-4E90-AFA9-952B417E12E8
# 295  2025-07-29  3596649C-1D05-4E90-AFA9-952B417E12E8
#
#                        GenericName                               TradeName  \
# 0    Alprazolam tablet 0.25 mg/tab  Alprazolam tablets 0.25 mg (Polipharm)
# 1    Alprazolam tablet 0.25 mg/tab  Alprazolam tablets 0.25 mg (Polipharm)
# 2    Alprazolam tablet 0.25 mg/tab  Alprazolam tablets 0.25 mg (Polipharm)
# 3    Alprazolam tablet 0.25 mg/tab  Alprazolam tablets 0.25 mg (Polipharm)
# 4    Alprazolam tablet 0.25 mg/tab  Alprazolam tablets 0.25 mg (Polipharm)
# ..                             ...                                     ...
# 291  Alprazolam tablet 0.25 mg/tab  Alprazolam tablets 0.25 mg (Polipharm)
# 292  Alprazolam tablet 0.25 mg/tab  Alprazolam tablets 0.25 mg (Polipharm)
# 293  Alprazolam tablet 0.25 mg/tab  Alprazolam tablets 0.25 mg (Polipharm)
# 294  Alprazolam tablet 0.25 mg/tab  Alprazolam tablets 0.25 mg (Polipharm)
# 295  Alprazolam tablet 0.25 mg/tab  Alprazolam tablets 0.25 mg (Polipharm)
#
#                      ProductTypeName  ProductPricePerUnit  ProductPrice  \
# 0                                NaN                 60.0             0
# 1    (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                 60.0             0
# 2    (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                 60.0             0
# 3    (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                 60.0             0
# 4    (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                 60.0             0
# ..                               ...                  ...           ...
# 291  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                 60.0             0
# 292  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                 60.0             0
# 293  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                 60.0             0
# 294  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                 60.0             0
# 295  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                 60.0             0
#
#      ProductStatus  ProductRemark                       ProductUnitCode  \
# 0                0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 1                0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 2                0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 3                0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 4                0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# ..             ...            ...                                   ...
# 291              0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 292              0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 293              0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 294              0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 295              0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
#
#     ProductUnitName  ProductAll  ProductRemain  ProductAllocated enum_stock
# 0               Box         NaN            0.0             200.0        NaN
# 1               Box         NaN            0.0             200.0        NaN
# 2               Box         NaN            0.0             200.0  ยาขาดคราว
# 3               Box         NaN         3340.0            4320.0       ปกติ
# 4               Box         NaN         3217.0            4443.0       ปกติ
# ..              ...         ...            ...               ...        ...
# 291             Box     40631.0        39623.0            1008.0       ปกติ
# 292             Box     39897.0        39416.0             481.0       ปกติ
# 293             Box     39897.0        39416.0             481.0       ปกติ
# 294             Box     39897.0        39416.0             481.0       ปกติ
# 295             Box     39897.0        39416.0             481.0       ปกติ
#
# [296 rows x 15 columns]

# %%
df.loc[df['TradeName'] == alp_tname1].sort_values(by='ProductRemain',ascending=False)
# Out:
#                                  ProductCode                    GenericName  \
# 132389  3596649C-1D05-4E90-AFA9-952B417E12E8  Alprazolam tablet 0.25 mg/tab
# 132625  3596649C-1D05-4E90-AFA9-952B417E12E8  Alprazolam tablet 0.25 mg/tab
# 132802  3596649C-1D05-4E90-AFA9-952B417E12E8  Alprazolam tablet 0.25 mg/tab
# 132743  3596649C-1D05-4E90-AFA9-952B417E12E8  Alprazolam tablet 0.25 mg/tab
# 132684  3596649C-1D05-4E90-AFA9-952B417E12E8  Alprazolam tablet 0.25 mg/tab
# ...                                      ...                            ...
# 2179    3596649C-1D05-4E90-AFA9-952B417E12E8  Alprazolam tablet 0.25 mg/tab
# 2089    3596649C-1D05-4E90-AFA9-952B417E12E8  Alprazolam tablet 0.25 mg/tab
# 1999    3596649C-1D05-4E90-AFA9-952B417E12E8  Alprazolam tablet 0.25 mg/tab
# 1909    3596649C-1D05-4E90-AFA9-952B417E12E8  Alprazolam tablet 0.25 mg/tab
# 19      3596649C-1D05-4E90-AFA9-952B417E12E8  Alprazolam tablet 0.25 mg/tab
#
#                                      TradeName  \
# 132389  Alprazolam tablets 0.25 mg (Polipharm)
# 132625  Alprazolam tablets 0.25 mg (Polipharm)
# 132802  Alprazolam tablets 0.25 mg (Polipharm)
# 132743  Alprazolam tablets 0.25 mg (Polipharm)
# 132684  Alprazolam tablets 0.25 mg (Polipharm)
# ...                                        ...
# 2179    Alprazolam tablets 0.25 mg (Polipharm)
# 2089    Alprazolam tablets 0.25 mg (Polipharm)
# 1999    Alprazolam tablets 0.25 mg (Polipharm)
# 1909    Alprazolam tablets 0.25 mg (Polipharm)
# 19      Alprazolam tablets 0.25 mg (Polipharm)
#
#                         ProductTypeName  ProductPricePerUnit  ProductPrice  \
# 132389  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                 60.0             0
# 132625  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                 60.0             0
# 132802  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                 60.0             0
# 132743  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                 60.0             0
# 132684  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                 60.0             0
# ...                                 ...                  ...           ...
# 2179    (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                 60.0             0
# 2089    (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                 60.0             0
# 1999    (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                 60.0             0
# 1909    (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                 60.0             0
# 19                                  NaN                 60.0             0
#
#         ProductStatus  ProductRemark                       ProductUnitCode  \
# 132389              0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 132625              0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 132802              0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 132743              0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 132684              0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# ...               ...            ...                                   ...
# 2179                0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 2089                0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 1999                0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 1909                0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 19                  0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
#
#        ProductUnitName  ProductAll  ProductRemain  ProductAllocated  \
# 132389             Box         NaN        56580.0              84.0
# 132625             Box         NaN        56580.0              84.0
# 132802             Box         NaN        56580.0              84.0
# 132743             Box         NaN        56580.0              84.0
# 132684             Box         NaN        56580.0              84.0
# ...                ...         ...            ...               ...
# 2179               Box         NaN            0.0             200.0
# 2089               Box         NaN            0.0             200.0
# 1999               Box         NaN            0.0             200.0
# 1909               Box         NaN            0.0             200.0
# 19                 Box         NaN            0.0             200.0
#
#                  LastUpdate enum_stock
# 132389  2025-04-30 18:15:01       ปกติ
# 132625  2025-05-01 02:15:02       ปกติ
# 132802  2025-05-01 08:15:01       ปกติ
# 132743  2025-05-01 06:15:00       ปกติ
# 132684  2025-05-01 04:15:00       ปกติ
# ...                     ...        ...
# 2179    2024-10-09 14:14:56  ยาขาดคราว
# 2089    2024-10-09 12:15:06  ยาขาดคราว
# 1999    2024-10-09 10:14:52  ยาขาดคราว
# 1909    2024-10-09 08:14:55  ยาขาดคราว
# 19      2024-10-07 11:22:48        NaN
#
# [3229 rows x 15 columns]

# %%
df_concerta18 = df.loc[df['TradeName'] == alp_tname1].sort_values(by='LastUpdate')

# %%
df['ProductCode'].value_counts()
# Out:
# ProductCode
# 097EBCD3-0F75-4AC0-98AA-A33B8AED586B    3229
# 5B193506-F5CD-4317-8237-C43303A653C3    3229
# 6D9D125F-7918-43E6-A98C-9EFAD6CA21E0    3229
# 6F5A22E0-68F2-4734-A4B2-02F24155D291    3229
# F66B4597-B645-4294-9CF5-056AFEC4C60D    3229
#                                         ...
# A45F8FAC-0D10-465C-BD50-C69540536A49     265
# DDB2C134-CF34-4292-8FDB-348897C0261E     265
# DF49B681-A53E-4350-B016-0BBA27FE66BC     265
# A3B97B18-F4DA-4E7D-924F-3B148C0E1FF4     265
# AE433AC9-A861-4BBE-A0D8-346CC1ADAF4D     233
# Name: count, Length: 97, dtype: int64

# %%
df_concerta18_resam = df_concerta18.set_index('LastUpdate')
# Out:
# C:\Users\user\root_dir\src\envfda1\Lib\site-packages\pandas\core\indexes\base.py:7587: FutureWarning: Dtype inference on a pandas object (Series, Index, ExtensionArray) is deprecated. The Index constructor will keep the original dtype in the future. Call `infer_objects` on the result to get the old behavior.
#   return Index(sequences[0], name=names)

# %%
df_concerta18_resam
# Out:
#                                               ProductCode  \
# LastUpdate
# 2024-10-07 11:22:48  3596649C-1D05-4E90-AFA9-952B417E12E8
# 2024-10-07 12:14:49  3596649C-1D05-4E90-AFA9-952B417E12E8
# 2024-10-07 14:14:50  3596649C-1D05-4E90-AFA9-952B417E12E8
# 2024-10-07 16:14:49  3596649C-1D05-4E90-AFA9-952B417E12E8
# 2024-10-07 18:14:52  3596649C-1D05-4E90-AFA9-952B417E12E8
# ...                                                   ...
# 2025-07-29 06:15:11  3596649C-1D05-4E90-AFA9-952B417E12E8
# 2025-07-29 08:15:12  3596649C-1D05-4E90-AFA9-952B417E12E8
# 2025-07-29 10:15:13  3596649C-1D05-4E90-AFA9-952B417E12E8
# 2025-07-29 12:15:14  3596649C-1D05-4E90-AFA9-952B417E12E8
# 2025-07-29 14:15:10  3596649C-1D05-4E90-AFA9-952B417E12E8
#
#                                        GenericName  \
# LastUpdate
# 2024-10-07 11:22:48  Alprazolam tablet 0.25 mg/tab
# 2024-10-07 12:14:49  Alprazolam tablet 0.25 mg/tab
# 2024-10-07 14:14:50  Alprazolam tablet 0.25 mg/tab
# 2024-10-07 16:14:49  Alprazolam tablet 0.25 mg/tab
# 2024-10-07 18:14:52  Alprazolam tablet 0.25 mg/tab
# ...                                            ...
# 2025-07-29 06:15:11  Alprazolam tablet 0.25 mg/tab
# 2025-07-29 08:15:12  Alprazolam tablet 0.25 mg/tab
# 2025-07-29 10:15:13  Alprazolam tablet 0.25 mg/tab
# 2025-07-29 12:15:14  Alprazolam tablet 0.25 mg/tab
# 2025-07-29 14:15:10  Alprazolam tablet 0.25 mg/tab
#
#                                                   TradeName  \
# LastUpdate
# 2024-10-07 11:22:48  Alprazolam tablets 0.25 mg (Polipharm)
# 2024-10-07 12:14:49  Alprazolam tablets 0.25 mg (Polipharm)
# 2024-10-07 14:14:50  Alprazolam tablets 0.25 mg (Polipharm)
# 2024-10-07 16:14:49  Alprazolam tablets 0.25 mg (Polipharm)
# 2024-10-07 18:14:52  Alprazolam tablets 0.25 mg (Polipharm)
# ...                                                     ...
# 2025-07-29 06:15:11  Alprazolam tablets 0.25 mg (Polipharm)
# 2025-07-29 08:15:12  Alprazolam tablets 0.25 mg (Polipharm)
# 2025-07-29 10:15:13  Alprazolam tablets 0.25 mg (Polipharm)
# 2025-07-29 12:15:14  Alprazolam tablets 0.25 mg (Polipharm)
# 2025-07-29 14:15:10  Alprazolam tablets 0.25 mg (Polipharm)
#
#                                      ProductTypeName  ProductPricePerUnit  \
# LastUpdate
# 2024-10-07 11:22:48                              NaN                 60.0
# 2024-10-07 12:14:49                              NaN                 60.0
# 2024-10-07 14:14:50                              NaN                 60.0
# 2024-10-07 16:14:49                              NaN                 60.0
# 2024-10-07 18:14:52                              NaN                 60.0
# ...                                              ...                  ...
# 2025-07-29 06:15:11  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                 60.0
# 2025-07-29 08:15:12  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                 60.0
# 2025-07-29 10:15:13  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                 60.0
# 2025-07-29 12:15:14  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                 60.0
# 2025-07-29 14:15:10  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                 60.0
#
#                      ProductPrice  ProductStatus  ProductRemark  \
# LastUpdate
# 2024-10-07 11:22:48             0              0            NaN
# 2024-10-07 12:14:49             0              0            NaN
# 2024-10-07 14:14:50             0              0            NaN
# 2024-10-07 16:14:49             0              0            NaN
# 2024-10-07 18:14:52             0              0            NaN
# ...                           ...            ...            ...
# 2025-07-29 06:15:11             0              0            NaN
# 2025-07-29 08:15:12             0              0            NaN
# 2025-07-29 10:15:13             0              0            NaN
# 2025-07-29 12:15:14             0              0            NaN
# 2025-07-29 14:15:10             0              0            NaN
#
#                                           ProductUnitCode ProductUnitName  \
# LastUpdate
# 2024-10-07 11:22:48  06E9F1D3-35B4-463C-B396-9D0E088B2AD0             Box
# 2024-10-07 12:14:49  06E9F1D3-35B4-463C-B396-9D0E088B2AD0             Box
# 2024-10-07 14:14:50  06E9F1D3-35B4-463C-B396-9D0E088B2AD0             Box
# 2024-10-07 16:14:49  06E9F1D3-35B4-463C-B396-9D0E088B2AD0             Box
# 2024-10-07 18:14:52  06E9F1D3-35B4-463C-B396-9D0E088B2AD0             Box
# ...                                                   ...             ...
# 2025-07-29 06:15:11  06E9F1D3-35B4-463C-B396-9D0E088B2AD0             Box
# 2025-07-29 08:15:12  06E9F1D3-35B4-463C-B396-9D0E088B2AD0             Box
# 2025-07-29 10:15:13  06E9F1D3-35B4-463C-B396-9D0E088B2AD0             Box
# 2025-07-29 12:15:14  06E9F1D3-35B4-463C-B396-9D0E088B2AD0             Box
# 2025-07-29 14:15:10  06E9F1D3-35B4-463C-B396-9D0E088B2AD0             Box
#
#                      ProductAll  ProductRemain  ProductAllocated enum_stock
# LastUpdate
# 2024-10-07 11:22:48         NaN            0.0             200.0        NaN
# 2024-10-07 12:14:49         NaN            0.0             200.0        NaN
# 2024-10-07 14:14:50         NaN            0.0             200.0        NaN
# 2024-10-07 16:14:49         NaN            0.0             200.0  ยาขาดคราว
# 2024-10-07 18:14:52         NaN            0.0             200.0  ยาขาดคราว
# ...                         ...            ...               ...        ...
# 2025-07-29 06:15:11     39897.0        39416.0             481.0       ปกติ
# 2025-07-29 08:15:12     39897.0        39416.0             481.0       ปกติ
# 2025-07-29 10:15:13     39857.0        39316.0             541.0       ปกติ
# 2025-07-29 12:15:14     39742.0        39316.0             426.0       ปกติ
# 2025-07-29 14:15:10     39742.0        39246.0             496.0       ปกติ
#
# [3229 rows x 14 columns]

# %%
df_concerta18_resam2 = df_concerta18_resam['ProductRemain'].resample('D').max().reset_index()

# %%
df_concerta18_resam2
# Out:
#     LastUpdate  ProductRemain
# 0   2024-10-07            0.0
# 1   2024-10-08            0.0
# 2   2024-10-09            0.0
# 3   2024-10-10         3340.0
# 4   2024-10-11         3217.0
# ..         ...            ...
# 291 2025-07-25        39623.0
# 292 2025-07-26        39416.0
# 293 2025-07-27        39416.0
# 294 2025-07-28        39416.0
# 295 2025-07-29        39416.0
#
# [296 rows x 2 columns]

# %%
# Now plot the resampled data
plt.figure(figsize=(12, 6)) # Adjust figure size for better readability
sns.lineplot(
    data=df_concerta18_resam,
    x='LastUpdate',
    y='ProductRemain',
    # hue='enum_type',
    # marker='o', # Add markers for each data point
    errorbar=None
)

# Add title and labels for clarity
plt.title(f'Resampled Daily Max and Min {alp_tname1} ProductRemain Over Time', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('ProductRemain(Units)', fontsize=12)
plt.legend(title='Extrema Type')

# Display the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df_concerta18_resam = df_concerta18.groupby(by=['LastUpdate'])

# %%
name_pivot = ['ProductAll', 'ProductRemain', 'ProductAllocated']
df_concerta18_unpivot = df_concerta18.melt(
    id_vars = [col for col in df_concerta18.columns.tolist() if col not in name_pivot],
    value_vars=['ProductAll', 'ProductRemain', 'ProductAllocated'],
    var_name='enum_type',
    value_name='values'
)

# %%
df_concerta18_unpivot
# Out:
#                                ProductCode  \
# 0     A9390303-63DA-47CB-B748-A0C4CB74FCAA
# 1     A9390303-63DA-47CB-B748-A0C4CB74FCAA
# 2     A9390303-63DA-47CB-B748-A0C4CB74FCAA
# 3     A9390303-63DA-47CB-B748-A0C4CB74FCAA
# 4     A9390303-63DA-47CB-B748-A0C4CB74FCAA
# ...                                    ...
# 9682  A9390303-63DA-47CB-B748-A0C4CB74FCAA
# 9683  A9390303-63DA-47CB-B748-A0C4CB74FCAA
# 9684  A9390303-63DA-47CB-B748-A0C4CB74FCAA
# 9685  A9390303-63DA-47CB-B748-A0C4CB74FCAA
# 9686  A9390303-63DA-47CB-B748-A0C4CB74FCAA
#
#                                             GenericName  \
# 0     Methylphenidate HCl extended release tablets 1...
# 1     Methylphenidate HCl extended release tablets 1...
# 2     Methylphenidate HCl extended release tablets 1...
# 3     Methylphenidate HCl extended release tablets 1...
# 4     Methylphenidate HCl extended release tablets 1...
# ...                                                 ...
# 9682  Methylphenidate HCl extended release tablets 1...
# 9683  Methylphenidate HCl extended release tablets 1...
# 9684  Methylphenidate HCl extended release tablets 1...
# 9685  Methylphenidate HCl extended release tablets 1...
# 9686  Methylphenidate HCl extended release tablets 1...
#
#                                 TradeName                  ProductTypeName  \
# 0     Concerta tablets 18 mg (30 tab/bot)                              NaN
# 1     Concerta tablets 18 mg (30 tab/bot)                              NaN
# 2     Concerta tablets 18 mg (30 tab/bot)                              NaN
# 3     Concerta tablets 18 mg (30 tab/bot)                              NaN
# 4     Concerta tablets 18 mg (30 tab/bot)                              NaN
# ...                                   ...                              ...
# 9682  Concerta tablets 18 mg (30 tab/bot)  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2
# 9683  Concerta tablets 18 mg (30 tab/bot)  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2
# 9684  Concerta tablets 18 mg (30 tab/bot)  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2
# 9685  Concerta tablets 18 mg (30 tab/bot)  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2
# 9686  Concerta tablets 18 mg (30 tab/bot)  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2
#
#       ProductPricePerUnit  ProductPrice  ProductStatus  ProductRemark  \
# 0                  2400.0             0              0            NaN
# 1                  2400.0             0              0            NaN
# 2                  2400.0             0              0            NaN
# 3                  2400.0             0              0            NaN
# 4                  2400.0             0              0            NaN
# ...                   ...           ...            ...            ...
# 9682               2400.0             0              0            NaN
# 9683               2400.0             0              0            NaN
# 9684               2400.0             0              0            NaN
# 9685               2400.0             0              0            NaN
# 9686               2400.0             0              0            NaN
#
#                            ProductUnitCode ProductUnitName  \
# 0     4CE8E50B-80B3-4003-B2B6-9D08C97DD814          Bottle
# 1     4CE8E50B-80B3-4003-B2B6-9D08C97DD814          Bottle
# 2     4CE8E50B-80B3-4003-B2B6-9D08C97DD814          Bottle
# 3     4CE8E50B-80B3-4003-B2B6-9D08C97DD814          Bottle
# 4     4CE8E50B-80B3-4003-B2B6-9D08C97DD814          Bottle
# ...                                    ...             ...
# 9682  4CE8E50B-80B3-4003-B2B6-9D08C97DD814          Bottle
# 9683  4CE8E50B-80B3-4003-B2B6-9D08C97DD814          Bottle
# 9684  4CE8E50B-80B3-4003-B2B6-9D08C97DD814          Bottle
# 9685  4CE8E50B-80B3-4003-B2B6-9D08C97DD814          Bottle
# 9686  4CE8E50B-80B3-4003-B2B6-9D08C97DD814          Bottle
#
#               LastUpdate enum_stock      isRemoved         enum_type  values
# 0    2024-10-07 11:22:48        NaN            NaN        ProductAll     NaN
# 1    2024-10-07 12:14:49        NaN            NaN        ProductAll     NaN
# 2    2024-10-07 14:14:50        NaN            NaN        ProductAll     NaN
# 3    2024-10-07 16:14:49       ปกติ            NaN        ProductAll     NaN
# 4    2024-10-07 18:14:52  ยาขาดคราว            NaN        ProductAll     NaN
# ...                  ...        ...            ...               ...     ...
# 9682 2025-07-29 06:15:11      FALSE  ยาใกล้ขาดคราว  ProductAllocated  1039.0
# 9683 2025-07-29 08:15:12      FALSE  ยาใกล้ขาดคราว  ProductAllocated  1039.0
# 9684 2025-07-29 10:15:13      FALSE  ยาใกล้ขาดคราว  ProductAllocated   974.0
# 9685 2025-07-29 12:15:14      FALSE  ยาใกล้ขาดคราว  ProductAllocated   974.0
# 9686 2025-07-29 14:15:10      FALSE  ยาใกล้ขาดคราว  ProductAllocated   972.0
#
# [9687 rows x 15 columns]

# %%
# Now plot the resampled data
plt.figure(figsize=(12, 6)) # Adjust figure size for better readability
sns.lineplot(
    data=df_concerta18_unpivot,
    x='LastUpdate',
    y='values',
    hue='enum_type',
    # marker='o', # Add markers for each data point
    errorbar=None
)

# Add title and labels for clarity
plt.title('Daily Stock movements of Concerta tablets 18 mg (30 tab/bot) ProductRemain Over Time', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('values', fontsize=12)
plt.legend(title='values Type')

# Display the plot
plt.show()

# %%
df_mid_small['deltaProductRemain'] = df_mid_small['ProductRemain'].diff().fillna(0)

# %%
df_mid_small.loc[df_mid_small['deltaProductRemain'] == 0]
# Out:
#                                ProductCode                      GenericName  \
# 0     6D9D125F-7918-43E6-A98C-9EFAD6CA21E0  Midazolam injection 5 mg/ml/amp
# 6     6D9D125F-7918-43E6-A98C-9EFAD6CA21E0  Midazolam injection 5 mg/ml/amp
# 7     6D9D125F-7918-43E6-A98C-9EFAD6CA21E0  Midazolam injection 5 mg/ml/amp
# 8     6D9D125F-7918-43E6-A98C-9EFAD6CA21E0  Midazolam injection 5 mg/ml/amp
# 9     6D9D125F-7918-43E6-A98C-9EFAD6CA21E0  Midazolam injection 5 mg/ml/amp
# ...                                    ...                              ...
# 2720  6D9D125F-7918-43E6-A98C-9EFAD6CA21E0  Midazolam injection 5 mg/ml/amp
# 2722  6D9D125F-7918-43E6-A98C-9EFAD6CA21E0  Midazolam injection 5 mg/ml/amp
# 2723  6D9D125F-7918-43E6-A98C-9EFAD6CA21E0  Midazolam injection 5 mg/ml/amp
# 2724  6D9D125F-7918-43E6-A98C-9EFAD6CA21E0  Midazolam injection 5 mg/ml/amp
# 2725  6D9D125F-7918-43E6-A98C-9EFAD6CA21E0  Midazolam injection 5 mg/ml/amp
#
#                                               TradeName  \
# 0     Midazolam-Hameln inj 5 mg/ml (Siam Bioscience)...
# 6     Midazolam-Hameln inj 5 mg/ml (Siam Bioscience)...
# 7     Midazolam-Hameln inj 5 mg/ml (Siam Bioscience)...
# 8     Midazolam-Hameln inj 5 mg/ml (Siam Bioscience)...
# 9     Midazolam-Hameln inj 5 mg/ml (Siam Bioscience)...
# ...                                                 ...
# 2720  Midazolam-Hameln inj 5 mg/ml (Siam Bioscience)...
# 2722  Midazolam-Hameln inj 5 mg/ml (Siam Bioscience)...
# 2723  Midazolam-Hameln inj 5 mg/ml (Siam Bioscience)...
# 2724  Midazolam-Hameln inj 5 mg/ml (Siam Bioscience)...
# 2725  Midazolam-Hameln inj 5 mg/ml (Siam Bioscience)...
#
#                       ProductTypeName  ProductPricePerUnit  ProductPrice  \
# 0                                 NaN                150.0             0
# 6     (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                150.0             0
# 7     (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                150.0             0
# 8     (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                150.0             0
# 9     (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                150.0             0
# ...                               ...                  ...           ...
# 2720  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                150.0             0
# 2722  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                150.0             0
# 2723  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                150.0             0
# 2724  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                150.0             0
# 2725  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                150.0             0
#
#       ProductStatus  ProductRemark                       ProductUnitCode  \
# 0                 0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 6                 0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 7                 0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 8                 0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 9                 0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# ...             ...            ...                                   ...
# 2720              0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 2722              0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 2723              0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 2724              0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 2725              0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
#
#      ProductUnitName  ProductRemain ProductAllocated           LastUpdate  \
# 0                Box         279445            3,511  2024-10-07 11:22:48
# 6                Box         278832            2,917  2024-10-07 22:14:49
# 7                Box         278832            2,917  2024-10-08 02:14:54
# 8                Box         278832            2,917  2024-10-08 04:14:51
# 9                Box         278832            2,917  2024-10-08 06:14:59
# ...              ...            ...              ...                  ...
# 2720             Box         171823            7,460  2025-06-16 22:15:03
# 2722             Box         171876            7,407  2025-06-17 02:15:04
# 2723             Box         171876            7,407  2025-06-17 04:15:02
# 2724             Box         171876            7,407  2025-06-17 06:15:04
# 2725             Box         171876            7,407  2025-06-17 08:15:02
#
#      enum_stock isRemoved     daylog  deltaProductRemain
# 0           NaN       NaN  10/7/2024                 0.0
# 6           NaN       NaN  10/7/2024                 0.0
# 7           NaN       NaN  10/8/2024                 0.0
# 8           NaN       NaN  10/8/2024                 0.0
# 9           NaN       NaN  10/8/2024                 0.0
# ...         ...       ...        ...                 ...
# 2720       ปกติ     False  6/16/2025                 0.0
# 2722       ปกติ     False  6/17/2025                 0.0
# 2723       ปกติ     False  6/17/2025                 0.0
# 2724       ปกติ     False  6/17/2025                 0.0
# 2725       ปกติ     False  6/17/2025                 0.0
#
# [1792 rows x 17 columns]

# %%
df_mid_small['deltaProductRemain_Sold'] = -df_mid_small['deltaProductRemain']

# %% [markdown]
# <h1> detect restock events</h1>

# %%
df_mid_small['deltaProductRemain_Sold'] = df_mid_small['deltaProductRemain_Sold'].apply(lambda x: x if x > 0 else 0)

# %%
df_mid_small = df_mid_small.loc[df_mid_small['deltaProductRemain'] != 0]

# %%
df_mid_small['deltaTime'] = df_mid_small['LastUpdate'].diff()

# %%
df_mid_small['deltaTime'] = df_mid_small['deltaTime'].fillna(pd.Timedelta(seconds=0))

# %%
df_mid_small['deltaTime_hours'] = df_mid_small['deltaTime'].dt.total_seconds() / 3600

# %%
df_mid_small.loc[0, 'deltaTime_hours'] = np.nan

# %%
df_mid_small['SaleRate_Per_Hour'] = df_mid_small['deltaProductRemain_Sold'] / df_mid_small['deltaTime_hours']

# %%
df_mid_small['SaleRate_Per_Hour'] = df_mid_small['SaleRate_Per_Hour'].replace([np.inf, -np.inf], np.nan).fillna(0)

# %%
df_mid_small
# Out:
#                                ProductCode                      GenericName  \
# 1     6D9D125F-7918-43E6-A98C-9EFAD6CA21E0  Midazolam injection 5 mg/ml/amp
# 2     6D9D125F-7918-43E6-A98C-9EFAD6CA21E0  Midazolam injection 5 mg/ml/amp
# 3     6D9D125F-7918-43E6-A98C-9EFAD6CA21E0  Midazolam injection 5 mg/ml/amp
# 4     6D9D125F-7918-43E6-A98C-9EFAD6CA21E0  Midazolam injection 5 mg/ml/amp
# 5     6D9D125F-7918-43E6-A98C-9EFAD6CA21E0  Midazolam injection 5 mg/ml/amp
# ...                                    ...                              ...
# 2716  6D9D125F-7918-43E6-A98C-9EFAD6CA21E0  Midazolam injection 5 mg/ml/amp
# 2717  6D9D125F-7918-43E6-A98C-9EFAD6CA21E0  Midazolam injection 5 mg/ml/amp
# 2718  6D9D125F-7918-43E6-A98C-9EFAD6CA21E0  Midazolam injection 5 mg/ml/amp
# 2721  6D9D125F-7918-43E6-A98C-9EFAD6CA21E0  Midazolam injection 5 mg/ml/amp
# 0                                      NaN                              NaN
#
#                                               TradeName  \
# 1     Midazolam-Hameln inj 5 mg/ml (Siam Bioscience)...
# 2     Midazolam-Hameln inj 5 mg/ml (Siam Bioscience)...
# 3     Midazolam-Hameln inj 5 mg/ml (Siam Bioscience)...
# 4     Midazolam-Hameln inj 5 mg/ml (Siam Bioscience)...
# 5     Midazolam-Hameln inj 5 mg/ml (Siam Bioscience)...
# ...                                                 ...
# 2716  Midazolam-Hameln inj 5 mg/ml (Siam Bioscience)...
# 2717  Midazolam-Hameln inj 5 mg/ml (Siam Bioscience)...
# 2718  Midazolam-Hameln inj 5 mg/ml (Siam Bioscience)...
# 2721  Midazolam-Hameln inj 5 mg/ml (Siam Bioscience)...
# 0                                                   NaN
#
#                       ProductTypeName  ProductPricePerUnit  ProductPrice  \
# 1                                 NaN                150.0           0.0
# 2                                 NaN                150.0           0.0
# 3                                 NaN                150.0           0.0
# 4                                 NaN                150.0           0.0
# 5                                 NaN                150.0           0.0
# ...                               ...                  ...           ...
# 2716  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                150.0           0.0
# 2717  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                150.0           0.0
# 2718  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                150.0           0.0
# 2721  (วจ. 2) วัตถุออกฤทธิ์ในประเภท 2                150.0           0.0
# 0                                 NaN                  NaN           NaN
#
#       ProductStatus  ProductRemark                       ProductUnitCode  \
# 1               0.0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 2               0.0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 3               0.0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 4               0.0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 5               0.0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# ...             ...            ...                                   ...
# 2716            0.0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 2717            0.0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 2718            0.0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 2721            0.0            NaN  06E9F1D3-35B4-463C-B396-9D0E088B2AD0
# 0               NaN            NaN                                   NaN
#
#      ProductUnitName  ProductRemain ProductAllocated          LastUpdate  \
# 1                Box       278945.0            4,011 2024-10-07 12:14:49
# 2                Box       278898.0            4,038 2024-10-07 14:14:50
# 3                Box       278867.0            2,882 2024-10-07 16:14:49
# 4                Box       278837.0            2,912 2024-10-07 18:14:52
# 5                Box       278832.0            2,917 2024-10-07 20:14:56
# ...              ...            ...              ...                 ...
# 2716             Box       173453.0            6,033 2025-06-16 14:15:01
# 2717             Box       171893.0            7,390 2025-06-16 16:15:05
# 2718             Box       171823.0            7,460 2025-06-16 18:15:05
# 2721             Box       171876.0            7,407 2025-06-17 00:15:04
# 0                NaN            NaN              NaN                 NaT
#
#      enum_stock isRemoved     daylog  deltaProductRemain  \
# 1           NaN       NaN  10/7/2024              -500.0
# 2           NaN       NaN  10/7/2024               -47.0
# 3          ปกติ       NaN  10/7/2024               -31.0
# 4          ปกติ       NaN  10/7/2024               -30.0
# 5          ปกติ       NaN  10/7/2024                -5.0
# ...         ...       ...        ...                 ...
# 2716       ปกติ     False  6/16/2025               -23.0
# 2717       ปกติ     False  6/16/2025             -1560.0
# 2718       ปกติ     False  6/16/2025               -70.0
# 2721       ปกติ     False  6/17/2025                53.0
# 0           NaN       NaN        NaN                 NaN
#
#       deltaProductRemain_Sold       deltaTime  deltaTime_hours  \
# 1                       500.0 0 days 00:00:00         0.000000
# 2                        47.0 0 days 02:00:01         2.000278
# 3                        31.0 0 days 01:59:59         1.999722
# 4                        30.0 0 days 02:00:03         2.000833
# 5                         5.0 0 days 02:00:04         2.001111
# ...                       ...             ...              ...
# 2716                     23.0 0 days 03:59:56         3.998889
# 2717                   1560.0 0 days 02:00:04         2.001111
# 2718                     70.0 0 days 02:00:00         2.000000
# 2721                      0.0 0 days 05:59:59         5.999722
# 0                         NaN             NaT              NaN
#
#       SaleRate_Per_Hour  SaleRate_Per_Hour_Interval        Date
# 1              0.000000                    0.000000  2024-10-07
# 2             23.496737                   23.496737  2024-10-07
# 3             15.502153                   15.502153  2024-10-07
# 4             14.993753                   14.993753  2024-10-07
# 5              2.498612                    2.498612  2024-10-07
# ...                 ...                         ...         ...
# 2716           5.751598                    5.751598  2025-06-16
# 2717         779.566907                  779.566907  2025-06-16
# 2718          35.000000                   35.000000  2025-06-16
# 2721           0.000000                    0.000000  2025-06-17
# 0              0.000000                    0.000000         NaT
#
# [935 rows x 23 columns]

# %%
df_mid_small['SaleRate_Per_Hour_Interval'] = df_mid_small['deltaProductRemain_Sold'] / df_mid_small['deltaTime_hours']

# %%
df_mid_small['SaleRate_Per_Hour_Interval'] = df_mid_small['SaleRate_Per_Hour_Interval'].replace([np.inf, -np.inf], np.nan).fillna(0)

# %%
df_mid_small['LastUpdate'] = pd.to_datetime(df_mid_small['LastUpdate'])

# %%
df_mid_small['Date'] = df_mid_small['LastUpdate'].dt.date

# %%
df_mid_small['LastUpdate'].dtype
# Out:
# dtype('<M8[ns]')

# %%
daily_summary = df_mid_small.groupby('Date').agg(
    TotalProductsSold=('deltaProductRemain_Sold', 'sum'),
    TotalTimeElapsedHours=('deltaTime_hours', 'sum')
).reset_index()

# %%
daily_summary['DailyAvgSaleRate_Per_Hour'] = daily_summary['TotalProductsSold'] / daily_summary['TotalTimeElapsedHours']

# %%
daily_summary['DailyAvgSaleRate_Per_Hour'] = daily_summary['DailyAvgSaleRate_Per_Hour'].replace([np.inf, -np.inf], np.nan).fillna(0)

# %%
daily_summary['DailyTotalSales'] = daily_summary['TotalProductsSold']

# %%
daily_summary
# Out:
#            Date  TotalProductsSold  TotalTimeElapsedHours  \
# 0    2024-10-07              613.0               8.001944
# 1    2024-10-08             2097.0              21.998333
# 2    2024-10-09             2686.0              24.000833
# 3    2024-10-10             1989.0              28.074722
# 4    2024-10-11              614.0              19.924444
# ..          ...                ...                    ...
# 232  2025-06-13             1951.0              19.998889
# 233  2025-06-14              141.0              26.000000
# 234  2025-06-15               67.0              21.999722
# 235  2025-06-16             2239.0              24.000833
# 236  2025-06-17                0.0               5.999722
#
#      DailyAvgSaleRate_Per_Hour  DailyTotalSales
# 0                    76.606380            613.0
# 1                    95.325403           2097.0
# 2                   111.912781           2686.0
# 3                    70.846649           1989.0
# 4                    30.816418            614.0
# ..                         ...              ...
# 232                  97.555420           1951.0
# 233                   5.423077            141.0
# 234                   3.045493             67.0
# 235                  93.288427           2239.0
# 236                   0.000000              0.0
#
# [237 rows x 5 columns]

# %%
daily_summary.loc[daily_summary['DailyTotalSales']==0]
# Out:
#            Date  TotalProductsSold  TotalTimeElapsedHours  \
# 15   2024-10-23                0.0               8.000000
# 23   2024-11-02                0.0              25.999167
# 42   2024-11-23                0.0               8.002500
# 59   2024-12-10                0.0              10.046111
# 101  2025-01-25                0.0               8.001111
# 213  2025-05-24                0.0               4.000000
# 236  2025-06-17                0.0               5.999722
#
#      DailyAvgSaleRate_Per_Hour  DailyTotalSales
# 15                         0.0              0.0
# 23                         0.0              0.0
# 42                         0.0              0.0
# 59                         0.0              0.0
# 101                        0.0              0.0
# 213                        0.0              0.0
# 236                        0.0              0.0

# %%
daily_summary2 = daily_summary.loc[daily_summary['DailyTotalSales']!=0]

# %%
sns.lineplot(data=daily_summary2, x='Date', y='DailyTotalSales', errorbar=None)
# Out:
# <Axes: xlabel='Date', ylabel='DailyTotalSales'>

# %%
daily_summary['DailyTotalSales'].mean()
# Out:
# 992.7299578059071

# %%
daily_summary['DailyTotalSales'].std()
# Out:
# 1038.763657066801

# %%
mean_daily_sale = daily_summary['DailyTotalSales'].mean()
std_daily_sale = daily_summary['DailyTotalSales'].std()

# %%
hours_per_day = 24
mean_hourly_sales = mean_daily_sale / hours_per_day
print(f"Mean Hourly Sales: {mean_hourly_sales:.4f} units/hour")
# Out:
# Mean Hourly Sales: 41.3637 units/hour

# %%
std_daily_sale
# Out:
# 1038.763657066801

# %%
std_hourly_for_band = std_daily_sale / hours_per_day

# %%
print(f"Sample standard deviation: {std_hourly_for_band:.4f}")
# Out:
# Sample standard deviation: 43.2818

# %%
print(f"z_score: {z_score:.2f}")
# Out:
# z_score: 1.00

# %%
last_observed_time = df_mid_small['LastUpdate'].max()

# %%
extrapolation_period_days = 360

# %%
future_hours = extrapolation_period_days * hours_per_day

# %%
future_timestamps = pd.to_datetime(
    [last_observed_time + pd.Timedelta(hours=i) for i in range(1, future_hours + 1)]
)

# %%
extrapolated_df = pd.DataFrame({
    'LastUpdate': future_timestamps
})

# %%
len(df_mid_small['ProductRemain'])
# Out:
# 935

# %%
df_mid_small['ProductRemain'].tail(5)
# Out:
# 2716    173453.0
# 2717    171893.0
# 2718    171823.0
# 2721    171876.0
# 0            NaN
# Name: ProductRemain, dtype: float64

# %%
last_product_remain = df_mid_small['ProductRemain'].iloc[len(df_mid_small['ProductRemain'])-2]

# %%
last_product_remain
# Out:
# 171876.0

# %%
mean_hourly_sales
# Out:
# 41.363748241912795

# %%
future_hours
# Out:
# 2160

# %%
projected_product_remain = [last_product_remain - (mean_hourly_sales * i) for i in range(1, future_hours + 1)]

# %%
extrapolated_df['ProductRemain_Mean'] = projected_product_remain

# %%
z_score = 1

# %%
extrapolated_df['Cumulative_Hours_From_Last'] = (extrapolated_df['LastUpdate'] - last_observed_time).dt.total_seconds() / 3600

# %%
extrapolated_df['Cumulative_Days_From_Last'] = extrapolated_df['Cumulative_Hours_From_Last'] / hours_per_day

# %%
extrapolated_df
# Out:
#               LastUpdate  ProductRemain_Mean  Cumulative_Hours_From_Last  \
# 0    2025-06-17 01:15:04       171834.636252                         1.0
# 1    2025-06-17 02:15:04       171793.272504                         2.0
# 2    2025-06-17 03:15:04       171751.908755                         3.0
# 3    2025-06-17 04:15:04       171710.545007                         4.0
# 4    2025-06-17 05:15:04       171669.181259                         5.0
# ...                  ...                 ...                         ...
# 8635 2026-06-11 20:15:04      -185341.329817                      8636.0
# 8636 2026-06-11 21:15:04      -185382.693565                      8637.0
# 8637 2026-06-11 22:15:04      -185424.057314                      8638.0
# 8638 2026-06-11 23:15:04      -185465.421062                      8639.0
# 8639 2026-06-12 00:15:04      -185506.784810                      8640.0
#
#       Cumulative_Days_From_Last
# 0                      0.041667
# 1                      0.083333
# 2                      0.125000
# 3                      0.166667
# 4                      0.208333
# ...                         ...
# 8635                 359.833333
# 8636                 359.875000
# 8637                 359.916667
# 8638                 359.958333
# 8639                 360.000000
#
# [8640 rows x 4 columns]

# %%
extrapolated_df['ProductRemain_Upper'] = extrapolated_df['ProductRemain_Mean'] + (z_score * std_daily_sale * np.sqrt(extrapolated_df['Cumulative_Days_From_Last']))
extrapolated_df['ProductRemain_Lower'] = extrapolated_df['ProductRemain_Mean'] - (z_score * std_daily_sale * np.sqrt(extrapolated_df['Cumulative_Days_From_Last']))

# %%
extrapolated_df['ProductRemain_Lower'] = extrapolated_df['ProductRemain_Lower'].clip(lower=0)
extrapolated_df['ProductRemain_Mean'] = extrapolated_df['ProductRemain_Mean'].clip(lower=0) # Cap mean at 0 too
extrapolated_df['ProductRemain_Upper'] = extrapolated_df['ProductRemain_Upper'].clip(lower=0)

# %%
extrapolated_df = extrapolated_df.loc[extrapolated_df['ProductRemain_Mean'] >0]

# %%
extrapolated_df
# Out:
#               LastUpdate  ProductRemain_Mean  Cumulative_Hours_From_Last  \
# 0    2025-06-17 01:15:04       171834.636252                         1.0
# 1    2025-06-17 02:15:04       171793.272504                         2.0
# 2    2025-06-17 03:15:04       171751.908755                         3.0
# 3    2025-06-17 04:15:04       171710.545007                         4.0
# 4    2025-06-17 05:15:04       171669.181259                         5.0
# ...                  ...                 ...                         ...
# 4150 2025-12-06 23:15:04          175.081048                      4151.0
# 4151 2025-12-07 00:15:04          133.717300                      4152.0
# 4152 2025-12-07 01:15:04           92.353551                      4153.0
# 4153 2025-12-07 02:15:04           50.989803                      4154.0
# 4154 2025-12-07 03:15:04            9.626055                      4155.0
#
#       Cumulative_Days_From_Last  ProductRemain_Upper  ProductRemain_Lower
# 0                      0.041667        172046.672995        171622.599508
# 1                      0.083333        172093.137742        171493.407265
# 2                      0.125000        172119.167168        171384.650342
# 3                      0.166667        172134.618494        171286.471520
# 4                      0.208333        172143.309831        171195.052686
# ...                         ...                  ...                  ...
# 4150                 172.958333         13836.238364             0.000000
# 4151                 173.000000         13796.520043             0.000000
# 4152                 173.041667         13756.801523             0.000000
# 4153                 173.083333         13717.082806             0.000000
# 4154                 173.125000         13677.363890             0.000000
#
# [4155 rows x 6 columns]

# %%
last_lowerProjectedDate = None
for i,row in extrapolated_df.iterrows():
    if row.loc['ProductRemain_Lower'] == 0:
        last_lowerProjectedDate = row.loc['LastUpdate']
        break

# %%
last_lowerProjectedDate
# Out:
# Timestamp('2025-11-23 22:15:04')

# %%
lastRemainsDate = extrapolated_df.iloc[len(extrapolated_df)-1,0]

# %%
lastRemainsDate
# Out:
# Timestamp('2025-12-07 03:15:04')

# %%
# Create a common column 'ProductRemain' for plotting observed data
df_observed_plot = df_mid_small[['LastUpdate', 'ProductRemain']].copy()
df_observed_plot['Type'] = 'Observed'

# Prepare extrapolated data for plotting
df_extrapolated_plot = extrapolated_df[['LastUpdate', 'ProductRemain_Mean']].copy()
df_extrapolated_plot['ProductRemain'] = df_extrapolated_plot['ProductRemain_Mean']
df_extrapolated_plot['Type'] = 'Extrapolated Mean'

# Concatenate for plotting the main lines
df_combined = pd.concat([df_observed_plot, df_extrapolated_plot])

plt.figure(figsize=(14, 7))

# Plot observed data
sns.lineplot(data=df_observed_plot, x='LastUpdate', y='ProductRemain', label='Observed Product Remain', color='blue', linewidth=2)

# Plot extrapolated mean
sns.lineplot(data=df_extrapolated_plot, x='LastUpdate', y='ProductRemain', label='Extrapolated Mean Sales', color='red', linestyle='--', linewidth=2)

# Plot the error band using fill_between
plt.fill_between(
    extrapolated_df['LastUpdate'],
    extrapolated_df['ProductRemain_Lower'],
    extrapolated_df['ProductRemain_Upper'],
    color='red',
    alpha=0.15,
    label=f'{z_score} Std Dev Error Band'
)

# Add a vertical line at the last observed point to separate observed from forecast
plt.axvline(last_observed_time, color='gray', linestyle=':', linewidth=1.5, label='Last Observed Data Point')
plt.axvline(last_lowerProjectedDate, color='red', linestyle=':', linewidth=1, label=f'Last Lower Projected Date: {last_lowerProjectedDate}')
plt.axvline(lastRemainsDate, color='red', linestyle=':', linewidth=1, label=f'Last Mean Projected Date: {lastRemainsDate}')

plt.title('Midazolam injection 5 mg/ml/amp Product Remain: Observed vs. Extrapolated Forecast with Error Band')
plt.xlabel('Date and Time')
plt.ylabel('Product Remain')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
